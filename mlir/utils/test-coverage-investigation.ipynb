# %% [markdown]
# # Test coverage investigation
# In this notebook, we analyze the data on what parameters are selected during various stages
# of lowering by `./get_test_metedata.py`.
#
# We aim to understand gaps in our test coverage and to identify over-represented code paths.
#
# This notebook was composed under Python 3.10. Other notable version numbers include Numpy 1.22, Pandas 1.4, and Jupyter >= 4.7

# %%
import numpy as np
import pandas as pd

import pickle
from typing import Iterable

# %%
METADATA_FILE = "test_metadata_2022_04_28.pickle"

# %%
with open(METADATA_FILE, 'rb') as f:
    raw_xdlops, raw_non_xdlops = pickle.load(f)

# %%
raw_xdlops[0]
# Out:
# {'Config': '--operation conv2d_bwd_weight -t f32 -p=false -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2',
#  'Filename': PosixPath('../../mlir/test/rocmlir-driver/auto_e2e/padding_kernel_gemmN.mlir'),
#  'Op': 'wrw',
#  'Filter layout': 'gkcyx',
#  'Input layout': 'ngchw',
#  'Output layout': 'ngkhw',
#  'g': 1,
#  'k': 64,
#  'c': 3,
#  'y': 7,
#  'x': 7,
#  'n': 256,
#  'hi': 224,
#  'wi': 224,
#  'ho': 112,
#  'wo': 112,
#  'Pad h left': 3,
#  'Pad h right': 2,
#  'Pad w left': 3,
#  'Pad w right': 2,
#  'Stride h': 2,
#  'Stride w': 2,
#  'Dilation h': 1,
#  'Dilation w': 1,
#  'Pad M': 0,
#  'Pad K': 0,
#  'Pad N': 45,
#  'Block size': 64,
#  'Grid size': 6,
#  'M': 64,
#  'K': 3211264,
#  'N': 192,
#  'M per block': 32,
#  'K per block': 4,
#  'N per block': 64,
#  'KPack': 1,
#  'M per wave': 32,
#  'N per wave': 64,
#  'Load A vector dim': 1,
#  'Load B vector dim': 1,
#  'Load A vector len': 1,
#  'Load type': 'f32',
#  'Load B vector len': 1,
#  'Load A intermediate len': 2,
#  'Load B intermediate len': 4,
#  'LDS store A len': 1,
#  'LDS store B len': 1,
#  'Store C vector dim': 4,
#  'Store C vector len': 1,
#  'Xdlop': 'mfma_f32_32x32x1f32'}

# %%
def to_touched_up_df(data) -> pd.DataFrame:
    ret = pd.DataFrame(data)
    for col in ["Load type", "Op", "Filter layout", "Input layout", "Output layout"]:
        ret[col] = ret[col].astype("category")
    ret["Filename"] = ret["Filename"].astype(str)
    ret["Filename"] = ret["Filename"].str.replace("../", "", regex=False)\
        .str.replace("mlir/test/rocmlir-driver/", "", regex=False)
    return ret

# %%
xdlops = to_touched_up_df(raw_xdlops)
non_xdlops = to_touched_up_df(raw_non_xdlops)

# %%
xdlops.head()
# Out:
#                                               Config  \
# 0  --operation conv2d_bwd_weight -t f32 -p=false ...
# 1  --operation conv2d_bwd_weight -t f16 -p=false ...
# 2  --operation conv2d_bwd_weight -t f32 -p=false ...
# 3  --operation conv2d_bwd_weight -t f16 -p=false ...
# 4  -fil_layout=yxck -in_layout=nhwc -out_layout=n...
#
#                                        Filename   Op Filter layout  \
# 0            auto_e2e/padding_kernel_gemmN.mlir  wrw         gkcyx
# 1            auto_e2e/padding_kernel_gemmN.mlir  wrw         gkcyx
# 2            auto_e2e/padding_kernel_gemmN.mlir  wrw         gkyxc
# 3            auto_e2e/padding_kernel_gemmN.mlir  wrw         gkyxc
# 4  auto_e2e/conv2d_host_validation_f32_fwd.mlir  fwd         gyxck
#
#   Input layout Output layout  g     k     c  y  ...  Load A vector len  \
# 0        ngchw         ngkhw  1    64     3  7  ...                  1
# 1        ngchw         ngkhw  1    64     3  7  ...                  1
# 2        nhwgc         nhwgk  1    64     3  7  ...                  1
# 3        nhwgc         nhwgk  1    64     3  7  ...                  1
# 4        nhwgc         nhwgk  1  1024  1024  1  ...                  2
#
#    Load type  Load B vector len  Load A intermediate len  \
# 0        f32                  1                        2
# 1        f16                  1                        2
# 2        f32                  1                        2
# 3        f16                  1                        2
# 4        f32                  2                        8
#
#    Load B intermediate len  LDS store A len  LDS store B len  \
# 0                        4                1                1
# 1                        4                1                1
# 2                        4                1                1
# 3                        4                1                1
# 4                        8                1                1
#
#    Store C vector dim  Store C vector len                Xdlop
# 0                   4                   1  mfma_f32_32x32x1f32
# 1                   4                   1  mfma_f32_32x32x4f16
# 2                   4                   1  mfma_f32_32x32x1f32
# 3                   4                   1  mfma_f32_32x32x4f16
# 4                   3                   4  mfma_f32_32x32x1f32
#
# [5 rows x 50 columns]

# %%
xdlops.shape
# Out:
# (662, 50)

# %%
non_xdlops.shape
# Out:
# (655, 47)

# %%
non_inherently_unique_cols_xdlops = xdlops.columns.drop(["Config", "Filename"])
non_inherently_unique_cols_xdlops
# Out:
# Index(['Op', 'Filter layout', 'Input layout', 'Output layout', 'g', 'k', 'c',
#        'y', 'x', 'n', 'hi', 'wi', 'ho', 'wo', 'Pad h left', 'Pad h right',
#        'Pad w left', 'Pad w right', 'Stride h', 'Stride w', 'Dilation h',
#        'Dilation w', 'Pad M', 'Pad K', 'Pad N', 'Block size', 'Grid size', 'M',
#        'K', 'N', 'M per block', 'K per block', 'N per block', 'KPack',
#        'M per wave', 'N per wave', 'Load A vector dim', 'Load B vector dim',
#        'Load A vector len', 'Load type', 'Load B vector len',
#        'Load A intermediate len', 'Load B intermediate len', 'LDS store A len',
#        'LDS store B len', 'Store C vector dim', 'Store C vector len', 'Xdlop'],
#       dtype='object')

# %%
non_inherently_unique_cols_non_xdlops = non_xdlops.columns.drop(["Config", "Filename"])
non_inherently_unique_cols_non_xdlops
# Out:
# Index(['Op', 'Filter layout', 'Input layout', 'Output layout', 'g', 'k', 'y',
#        'x', 'c', 'n', 'hi', 'wi', 'ho', 'wo', 'Pad h left', 'Pad h right',
#        'Pad w left', 'Pad w right', 'Stride h', 'Stride w', 'Dilation h',
#        'Dilation w', 'Pad M', 'Pad K', 'Pad N', 'Block size', 'Grid size', 'M',
#        'K', 'N', 'M per block', 'K per block', 'N per block', 'KPack',
#        'M per thread', 'N per thread', 'Load A vector dim',
#        'Load B vector dim', 'Load A vector len', 'Load type',
#        'Load B vector len', 'Load A intermediate len',
#        'Load B intermediate len', 'LDS store A len', 'LDS store B len'],
#       dtype='object')

# %%
def duplicates(df: pd.DataFrame, cols_to_test) -> pd.DataFrame:
    return df[df.duplicated(subset=cols_to_test, keep=False)]

# %%
xdlops_dups = duplicates(xdlops, non_inherently_unique_cols_xdlops)
for conf, group in xdlops_dups.groupby(list(non_inherently_unique_cols_xdlops)):
    print("Shared:", dict(zip(non_inherently_unique_cols_xdlops, conf)))
    for _, row in group.iterrows():
        print("Config:", row["Config"])
        print("File:", row["Filename"])
    print()
# Out:
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'c': 128, 'y': 3, 'x': 3, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 288, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d_bwd_data
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 3136, 'M': 256, 'K': 32, 'N': 200704, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'c': 64, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 25088, 'M': 64, 'K': 256, 'N': 200704, 'M per block': 8, 'K per block': 8, 'N per block': 64, 'KPack': 1, 'M per wave': 8, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 1, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_4x4x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 512, 'K': 64, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 128, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 1024, 'K': 128, 'N': 12544, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 1024, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 512, 'K': 256, 'N': 12544, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 2048, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 1024, 'K': 2048, 'N': 3136, 'M per block': 8, 'K per block': 8, 'N per block': 64, 'KPack': 1, 'M per wave': 8, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 1, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_4x4x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'c': 128, 'y': 3, 'x': 3, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 288, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d_bwd_data
# File: e2e_for_pr/Resnet50_validation_nhwc.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 3136, 'M': 256, 'K': 32, 'N': 200704, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'c': 64, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 25088, 'M': 64, 'K': 256, 'N': 200704, 'M per block': 8, 'K per block': 8, 'N per block': 64, 'KPack': 1, 'M per wave': 8, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 1, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_4x4x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 512, 'K': 64, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 128, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 1024, 'K': 128, 'N': 12544, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 1024, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 512, 'K': 256, 'N': 12544, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 2048, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 1024, 'K': 2048, 'N': 3136, 'M per block': 8, 'K per block': 8, 'N per block': 64, 'KPack': 1, 'M per wave': 8, 'N per wave': 64, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 1, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': -1, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_4x4x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 64, 'c': 3, 'y': 7, 'x': 7, 'n': 256, 'hi': 224, 'wi': 224, 'ho': 112, 'wo': 112, 'Pad h left': 3, 'Pad h right': 2, 'Pad w left': 3, 'Pad w right': 2, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 1, 'Pad N': 0, 'Block size': 64, 'Grid size': 100352, 'M': 64, 'K': 148, 'N': 3211264, 'M per block': 32, 'K per block': 4, 'N per block': 64, 'KPack': 1, 'M per wave': 32, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 2, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: --operation conv2d -t f32 -p=false -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmK.mlir
# Config: -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'c': 128, 'y': 3, 'x': 3, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 288, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x4f16'}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f16 --operation conv2d
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'c': 128, 'y': 3, 'x': 3, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 288, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'c': 128, 'y': 3, 'x': 3, 'n': 256, 'hi': 58, 'wi': 58, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 128, 'K': 288, 'N': 200704, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x4f16'}
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 128, 'K': 64, 'N': 200704, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 2, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'c': 64, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 3136, 'M': 256, 'K': 16, 'N': 200704, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 2, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'c': 256, 'y': 3, 'x': 3, 'n': 256, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 256, 'K': 576, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x4f16'}
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 256 --in_h 14 --in_w 14 --out_channels 256 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 1 --padding_w 1
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 256, 'K': 128, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 2, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 512, 'K': 64, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 512, 'K': 256, 'N': 12544, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 2, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 1024, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 1024, 'K': 128, 'N': 12544, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 2, 'Load A vector len': 2, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 2048, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 12544, 'M': 2048, 'K': 1024, 'N': 3136, 'M per block': 8, 'K per block': 8, 'N per block': 64, 'KPack': 1, 'M per wave': 8, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 1, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 4, 'Store C vector len': 1, 'Xdlop': 'mfma_f32_4x4x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 64, 'c': 3, 'y': 7, 'x': 7, 'n': 256, 'hi': 224, 'wi': 224, 'ho': 112, 'wo': 112, 'Pad h left': 3, 'Pad h right': 2, 'Pad w left': 3, 'Pad w right': 2, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 1, 'Pad N': 0, 'Block size': 64, 'Grid size': 100352, 'M': 64, 'K': 148, 'N': 3211264, 'M per block': 32, 'K per block': 4, 'N per block': 64, 'KPack': 1, 'M per wave': 32, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 2, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 3, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: --operation conv2d -t f32 -p=false -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmK.mlir
# Config: -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'c': 8, 'y': 1, 'x': 1, 'n': 128, 'hi': 32, 'wi': 32, 'ho': 32, 'wo': 32, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1024, 'M': 128, 'K': 8, 'N': 131072, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 3, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'c': 8, 'y': 1, 'x': 1, 'n': 128, 'hi': 32, 'wi': 32, 'ho': 32, 'wo': 32, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 2, 'Dilation w': 2, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1024, 'M': 128, 'K': 8, 'N': 131072, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 3, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=2 --dilation_w=2 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=2 --dilation_w=2 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'c': 128, 'y': 3, 'x': 3, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 288, 'N': 50176, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 3, 'Load B vector dim': 3, 'Load A vector len': 2, 'Load type': 'f16', 'Load B vector len': 2, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 3, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x4f16'}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f16 --operation conv2d
# ...
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=128 -in_h=58 -in_w=58 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 128, 'K': 3136, 'N': 256, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'c': 64, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 3136, 'N': 64, 'M per block': 8, 'K per block': 8, 'N per block': 64, 'KPack': 1, 'M per wave': 8, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 1, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_4x4x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'c': 256, 'y': 3, 'x': 3, 'n': 256, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 784, 'N': 2304, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: --operation conv2d_bwd_weight -t f32 -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -in_channels=256 -batchsize=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 -dilation_h=1 -dilation_w=1 -conv_stride_h=1 -conv_stride_w=1 -padding_h=1 -padding_w=1
# File: auto_e2e/conv2d_host_validation_f32_bwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 784, 'N': 512, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 196, 'N': 1024, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x4f16'}
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 1024 --in_h 14 --in_w 14 --out_channels 256 --fil_w 1 --fil_h 1 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'c': 256, 'y': 1, 'x': 1, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 512, 'K': 784, 'N': 256, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 512, 'K': 784, 'N': 1024, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 1024, 'c': 512, 'y': 1, 'x': 1, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 1024, 'K': 784, 'N': 512, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 2048, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 2048, 'K': 196, 'N': 1024, 'M per block': 128, 'K per block': 4, 'N per block': 128, 'KPack': 4, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x4f16'}
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 1024 --in_h 14 --in_w 14 --out_channels 2048 --fil_w 1 --fil_h 1 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 2048, 'c': 1024, 'y': 1, 'x': 1, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 2048, 'K': 784, 'N': 1024, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per wave': 64, 'N per wave': 64, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1, 'Store C vector dim': 5, 'Store C vector len': 4, 'Xdlop': 'mfma_f32_32x32x1f32'}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir

# %%
non_xdlops_dups = duplicates(non_xdlops, non_inherently_unique_cols_non_xdlops)
for conf, group in non_xdlops_dups.groupby(list(non_inherently_unique_cols_non_xdlops)):
    print("Shared:", dict(zip(non_inherently_unique_cols_non_xdlops, conf)))
    for _, row in group.iterrows():
        print("Config:", row["Config"])
        print("File:", row["Filename"])
    print()
# Out:
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 3136, 'M': 256, 'K': 128, 'N': 200704, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 1152, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d_bwd_data
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 64, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 3136, 'M': 64, 'K': 256, 'N': 200704, 'M per block': 64, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 16, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 512, 'K': 256, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 512, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 1024, 'K': 512, 'N': 12544, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 1024, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 512, 'K': 1024, 'N': 12544, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 2048, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 1024, 'K': 2048, 'N': 3136, 'M per block': 128, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 3136, 'M': 256, 'K': 128, 'N': 200704, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 1152, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d_bwd_data
# File: e2e_for_pr/Resnet50_validation_nhwc.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 64, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 3136, 'M': 64, 'K': 256, 'N': 200704, 'M per block': 64, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 16, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 512, 'K': 256, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 256, 'K': 512, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 1024, 'K': 512, 'N': 12544, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 1024, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 512, 'K': 1024, 'N': 12544, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'bwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 2048, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 64, 'Grid size': 512, 'M': 1024, 'K': 2048, 'N': 3136, 'M per block': 128, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 2, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_data -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 64, 'y': 7, 'x': 7, 'c': 3, 'n': 256, 'hi': 224, 'wi': 224, 'ho': 112, 'wo': 112, 'Pad h left': 3, 'Pad h right': 2, 'Pad w left': 3, 'Pad w right': 2, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 13, 'Pad N': 0, 'Block size': 64, 'Grid size': 50176, 'M': 64, 'K': 160, 'N': 3211264, 'M per block': 64, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 16, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --operation conv2d -t f32 -p=false -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmK.mlir
# Config: -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 128, 'K': 256, 'N': 200704, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 1152, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f16 --operation conv2d
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 1152, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 256, 'hi': 58, 'wi': 58, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 128, 'K': 1152, 'N': 200704, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 64, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 3136, 'M': 256, 'K': 64, 'N': 200704, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 256, 'K': 512, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 256, 'y': 3, 'x': 3, 'c': 256, 'n': 256, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 256, 'K': 2304, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 256 --in_h 14 --in_w 14 --out_channels 256 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 1 --padding_w 1
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 512, 'K': 256, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 512, 'K': 1024, 'N': 12544, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 1024, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 784, 'M': 1024, 'K': 512, 'N': 12544, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkcyx', 'Input layout': 'ngchw', 'Output layout': 'ngkhw', 'g': 1, 'k': 2048, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 128, 'Grid size': 784, 'M': 2048, 'K': 1024, 'N': 3136, 'M per block': 128, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 64, 'y': 7, 'x': 7, 'c': 3, 'n': 256, 'hi': 224, 'wi': 224, 'ho': 112, 'wo': 112, 'Pad h left': 3, 'Pad h right': 2, 'Pad w left': 3, 'Pad w right': 2, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 13, 'Pad N': 0, 'Block size': 64, 'Grid size': 50176, 'M': 64, 'K': 160, 'N': 3211264, 'M per block': 64, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 16, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --operation conv2d -t f32 -p=false -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmK.mlir
# Config: -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 1, 'x': 1, 'c': 8, 'n': 128, 'hi': 32, 'wi': 32, 'ho': 32, 'wo': 32, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1024, 'M': 128, 'K': 8, 'N': 131072, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 1, 'x': 1, 'c': 8, 'n': 128, 'hi': 32, 'wi': 32, 'ho': 32, 'wo': 32, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 2, 'Dilation w': 2, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1024, 'M': 128, 'K': 8, 'N': 131072, 'M per block': 128, 'K per block': 8, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 4, 'Load B intermediate len': 4, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=2 --dilation_w=2 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=2 --dilation_w=2 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 1568, 'M': 128, 'K': 256, 'N': 200704, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=128 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 1152, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f16', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f16 --operation conv2d
# File: e2e_for_pr/Resnet50_validation_nhwc.mlir
#
# Shared: {'Op': 'fwd', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 392, 'M': 128, 'K': 1152, 'N': 50176, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 1, 'Load A vector len': 4, 'Load type': 'f32', 'Load B vector len': 4, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# ...
# File: e2e_for_pr/Resnet50_validation_nhwc.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 9, 'M': 128, 'K': 50176, 'N': 1152, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f32 --operation conv2d_bwd_weight
# File: e2e_for_pr/Resnet50_validation_nhwc.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 128, 'y': 3, 'x': 3, 'c': 128, 'n': 64, 'hi': 58, 'wi': 58, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 9, 'M': 128, 'K': 50176, 'N': 1152, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=128 -in_h=58 -in_w=58 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 64, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 56, 'wo': 56, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 128, 'Grid size': 2, 'M': 256, 'K': 200704, 'N': 64, 'M per block': 128, 'K per block': 16, 'N per block': 64, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 16, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# Config: -batchsize=64 -in_channels=64 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 8, 'M': 256, 'K': 50176, 'N': 512, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 16, 'M': 256, 'K': 12544, 'N': 1024, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 1024 --in_h 14 --in_w 14 --out_channels 256 --fil_w 1 --fil_h 1 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 256, 'y': 3, 'x': 3, 'c': 256, 'n': 256, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 1, 'Pad h right': 1, 'Pad w left': 1, 'Pad w right': 1, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 36, 'M': 256, 'K': 50176, 'N': 2304, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --operation conv2d_bwd_weight -t f32 -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -in_channels=256 -batchsize=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 -dilation_h=1 -dilation_w=1 -conv_stride_h=1 -conv_stride_w=1 -padding_h=1 -padding_w=1
# File: auto_e2e/conv2d_host_validation_f32_bwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 256, 'n': 64, 'hi': 56, 'wi': 56, 'ho': 28, 'wo': 28, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 8, 'M': 512, 'K': 50176, 'N': 256, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# Config: -batchsize=64 -in_channels=256 -in_h=56 -in_w=56 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 512, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 1, 'Stride w': 1, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 32, 'M': 512, 'K': 12544, 'N': 1024, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=512 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 1024, 'y': 1, 'x': 1, 'c': 512, 'n': 64, 'hi': 28, 'wi': 28, 'ho': 14, 'wo': 14, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 32, 'M': 1024, 'K': 12544, 'N': 512, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# Config: -batchsize=64 -in_channels=512 -in_h=28 -in_w=28 -out_channels=1024 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 2048, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 128, 'M': 2048, 'K': 3136, 'N': 1024, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f16', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 1024 --in_h 14 --in_w 14 --out_channels 2048 --fil_w 1 --fil_h 1 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir
#
# Shared: {'Op': 'wrw', 'Filter layout': 'gkyxc', 'Input layout': 'nhwgc', 'Output layout': 'nhwgk', 'g': 1, 'k': 2048, 'y': 1, 'x': 1, 'c': 1024, 'n': 64, 'hi': 14, 'wi': 14, 'ho': 7, 'wo': 7, 'Pad h left': 0, 'Pad h right': 0, 'Pad w left': 0, 'Pad w right': 0, 'Stride h': 2, 'Stride w': 2, 'Dilation h': 1, 'Dilation w': 1, 'Pad M': 0, 'Pad K': 0, 'Pad N': 0, 'Block size': 256, 'Grid size': 128, 'M': 2048, 'K': 3136, 'N': 1024, 'M per block': 128, 'K per block': 16, 'N per block': 128, 'KPack': 1, 'M per thread': 4, 'N per thread': 4, 'Load A vector dim': 1, 'Load B vector dim': 2, 'Load A vector len': 1, 'Load type': 'f32', 'Load B vector len': 1, 'Load A intermediate len': 8, 'Load B intermediate len': 8, 'LDS store A len': 1, 'LDS store B len': 1}
# Config: -batchsize=64 -groupsize=1 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir

# %%
xdlops_dups.groupby("Filename").count()
# Out:
#                                                     Config  Op  Filter layout  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir          1   1              1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir          1   1              1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir          4   4              4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir          2   2              2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir          2   2              2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir          6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir         6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir         6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir         6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir         6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir         6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir          6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir          6   6              6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir          2   2              2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...       6   6              6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...       6   6              6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...       1   1              1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...       6   6              6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...       6   6              6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...       6   6              6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...       6   6              6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...       4   4              4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....       6   6              6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir             5   5              5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir             4   4              4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir             2   2              2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir             5   5              5
# auto_e2e/padding_kernel_gemmK.mlir                       2   2              2
# auto_e2e/padding_kernel_gemmN.mlir                       2   2              2
# e2e_for_pr/Resnet50_validation_nchw.mlir                 5   5              5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                 5   5              5
#
#                                                     Input layout  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir               6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir               6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir               6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir               6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir               6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...             6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...             6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...             1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...             6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...             6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...             6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...             6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...             4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....             6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                   5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                   4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                   2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                   5
# auto_e2e/padding_kernel_gemmK.mlir                             2
# auto_e2e/padding_kernel_gemmN.mlir                             2
# e2e_for_pr/Resnet50_validation_nchw.mlir                       5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                       5
#
#                                                     Output layout  g  k  c  y  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                 1  1  1  1  1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                 1  1  1  1  1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                 4  4  4  4  4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                 2  2  2  2  2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                 2  2  2  2  2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                 6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                 6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                 6  6  6  6  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                 2  2  2  2  2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...              6  6  6  6  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...              6  6  6  6  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...              1  1  1  1  1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...              6  6  6  6  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...              6  6  6  6  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...              6  6  6  6  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...              6  6  6  6  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...              4  4  4  4  4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....              6  6  6  6  6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                    5  5  5  5  5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                    4  4  4  4  4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                    2  2  2  2  2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                    5  5  5  5  5
# auto_e2e/padding_kernel_gemmK.mlir                              2  2  2  2  2
# auto_e2e/padding_kernel_gemmN.mlir                              2  2  2  2  2
# e2e_for_pr/Resnet50_validation_nchw.mlir                        5  5  5  5  5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                        5  5  5  5  5
#
#                                                     x  ...  Load A vector len  \
# Filename                                               ...
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir     1  ...                  1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir     1  ...                  1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir     4  ...                  4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir     2  ...                  2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir     2  ...                  2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir     6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir    6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir    6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir    6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir    6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir    6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir     6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir     6  ...                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir     2  ...                  2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...  6  ...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...  6  ...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...  1  ...                  1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...  6  ...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...  6  ...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...  6  ...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...  6  ...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...  4  ...                  4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....  6  ...                  6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir        5  ...                  5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir        4  ...                  4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir        2  ...                  2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir        5  ...                  5
# auto_e2e/padding_kernel_gemmK.mlir                  2  ...                  2
# auto_e2e/padding_kernel_gemmN.mlir                  2  ...                  2
# e2e_for_pr/Resnet50_validation_nchw.mlir            5  ...                  5
# e2e_for_pr/Resnet50_validation_nhwc.mlir            5  ...                  5
#
#                                                     Load type  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir             1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir             1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir             4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir             2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir             2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir             6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir            6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir            6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir            6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir            6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir            6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir             6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir             6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir             2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...          6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...          6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...          1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...          6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...          6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...          6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...          6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...          4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....          6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                5
# auto_e2e/padding_kernel_gemmK.mlir                          2
# auto_e2e/padding_kernel_gemmN.mlir                          2
# e2e_for_pr/Resnet50_validation_nchw.mlir                    5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                    5
#
#                                                     Load B vector len  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                     1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                     1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                     4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                     2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                     2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                    6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                    6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                    6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                    6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                    6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                     2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                  1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                  6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                  4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                  6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                        5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                        4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                        2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                        5
# auto_e2e/padding_kernel_gemmK.mlir                                  2
# auto_e2e/padding_kernel_gemmN.mlir                                  2
# e2e_for_pr/Resnet50_validation_nchw.mlir                            5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                            5
#
#                                                     Load A intermediate len  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                           1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                           1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                           4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                           2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                           2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                           6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                           6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                           6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                           2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                        1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                        4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                        6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                              5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                              4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                              2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                              5
# auto_e2e/padding_kernel_gemmK.mlir                                        2
# auto_e2e/padding_kernel_gemmN.mlir                                        2
# e2e_for_pr/Resnet50_validation_nchw.mlir                                  5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                                  5
#
#                                                     Load B intermediate len  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                           1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                           1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                           4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                           2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                           2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                           6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                          6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                           6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                           6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                           2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                        1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                        6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                        4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                        6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                              5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                              4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                              2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                              5
# auto_e2e/padding_kernel_gemmK.mlir                                        2
# auto_e2e/padding_kernel_gemmN.mlir                                        2
# e2e_for_pr/Resnet50_validation_nchw.mlir                                  5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                                  5
#
#                                                     LDS store A len  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                   1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                   1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                   4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                   2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                   2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                   6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                   6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                   6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                   2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                      5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                      4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                      2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                      5
# auto_e2e/padding_kernel_gemmK.mlir                                2
# auto_e2e/padding_kernel_gemmN.mlir                                2
# e2e_for_pr/Resnet50_validation_nchw.mlir                          5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                          5
#
#                                                     LDS store B len  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                   1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                   1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                   4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                   2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                   2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                   6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                  6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                   6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                   6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                   2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                      5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                      4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                      2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                      5
# auto_e2e/padding_kernel_gemmK.mlir                                2
# auto_e2e/padding_kernel_gemmN.mlir                                2
# e2e_for_pr/Resnet50_validation_nchw.mlir                          5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                          5
#
#                                                     Store C vector dim  \
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                      1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                      1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                      4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                      2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                      2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                     6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                      2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                   6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                   6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                   1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                   6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                   6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                   6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                   6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                   4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                   6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                         5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                         4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                         2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                         5
# auto_e2e/padding_kernel_gemmK.mlir                                   2
# auto_e2e/padding_kernel_gemmN.mlir                                   2
# e2e_for_pr/Resnet50_validation_nchw.mlir                             5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                             5
#
#                                                     Store C vector len  Xdlop
# Filename
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir                      1      1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir                      1      1
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir                      4      4
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir                      2      2
# auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir                      2      2
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir                      6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir                     6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir                     6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir                     6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir                     6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir                     6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir                      6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_4.mlir                      6      6
# auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir                      2      2
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_10...                   6      6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_15...                   6      6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_16...                   1      1
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_17...                   6      6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_19...                   6      6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_20...                   6      6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_22...                   6      6
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_23...                   4      4
# auto_e2e/Resnext101/F32_tests/Resnext101_f32_9....                   6      6
# auto_e2e/conv2d_host_validation_f16_bwd.mlir                         5      5
# auto_e2e/conv2d_host_validation_f16_fwd.mlir                         4      4
# auto_e2e/conv2d_host_validation_f32_bwd.mlir                         2      2
# auto_e2e/conv2d_host_validation_f32_fwd.mlir                         5      5
# auto_e2e/padding_kernel_gemmK.mlir                                   2      2
# auto_e2e/padding_kernel_gemmN.mlir                                   2      2
# e2e_for_pr/Resnet50_validation_nchw.mlir                             5      5
# e2e_for_pr/Resnet50_validation_nhwc.mlir                             5      5
#
# [31 rows x 49 columns]

# %%
xdlops_dups.shape
# Out:
# (137, 50)

# %%
non_xdlops_dups.shape
# Out:
# (137, 47)

# %%
for conf, group in non_xdlops_dups.groupby(list(non_inherently_unique_cols_non_xdlops)):
    conf = dict(zip(non_inherently_unique_cols_non_xdlops, conf))
    if conf["Op"] != "fwd" or conf["Input layout"] != "ngchw":
        continue
    if not (group["Filename"].str.contains("Resnext").any() and\
            group["Filename"].str.contains("Resnet").any()):
        continue
    for _, row in group.iterrows():
        print("File:", row["Filename"])
    print()
# Out:
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_15.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_11.mlir
#
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_22.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_20.mlir
#
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_20.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_17.mlir
#
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_17.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_12.mlir
#
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_10.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_3.mlir
#
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_19.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_15.mlir
#
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_9.mlir
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_1.mlir

# %%
for conf, group in non_xdlops_dups.groupby(list(non_inherently_unique_cols_non_xdlops)):
    if not group["Filename"].str.contains("padding_kernel").any():
        continue
    for _, row in group.iterrows():
        print("Config:", row["Config"])
        print("File:", row["Filename"])
    print()
# Out:
# Config: --operation conv2d -t f32 -p=false -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmK.mlir
# Config: -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Config: --operation conv2d -t f32 -p=false -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmK.mlir
# Config: -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Config: --operation conv2d_bwd_weight -t f32 -p=false -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmN.mlir
# Config: -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d_bwd_weight
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir
#
# Config: --operation conv2d_bwd_weight -t f32 -p=false -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -out_channels=64 -in_h=224 -in_w=224 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --padding_h=3 --padding_w=3 --conv_stride_h=2 --conv_stride_w=2
# File: auto_e2e/padding_kernel_gemmN.mlir
# Config: -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -batchsize=256 -groupsize=1 -in_channels=3 -in_h=224 -in_w=224 -out_channels=64 -fil_h=7 -fil_w=7 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=3 --padding_w=3 -t f32 --operation=conv2d_bwd_weight
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_23.mlir

# %%
for conf, group in non_xdlops_dups.groupby(list(non_inherently_unique_cols_non_xdlops)):
    if not group["Filename"].str.contains("host_validation").any():
        continue
    for _, row in group.iterrows():
        print("Config:", row["Config"])
        print("File:", row["Filename"])
    print()
# Out:
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
#
# Config: --rand_type float --operation conv2d -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 256 --in_channels 256 --in_h 14 --in_w 14 --out_channels 256 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 1 --padding_w 1
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir
#
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
#
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=2 --dilation_w=2 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -batchsize=128 -in_channels=8 -out_channels=128 -in_h=32 -in_w=32 -fil_h=1 -fil_w=1 --dilation_h=2 --dilation_w=2 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 -p=false
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
#
# Config: --rand_type float --operation conv2d -t f16 -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -in_channels=256 -batchsize=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 -dilation_h=1 -dilation_w=1 -conv_stride_h=1 -conv_stride_w=1 -padding_h=1 -padding_w=1
# File: auto_e2e/conv2d_host_validation_f16_fwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_9.mlir
#
# Config: --operation conv2d -t f32 -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -in_channels=256 -batchsize=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 -dilation_h=1 -dilation_w=1 -conv_stride_h=1 -conv_stride_w=1 -padding_h=1 -padding_w=1
# File: auto_e2e/conv2d_host_validation_f32_fwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir
#
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 64 --in_channels 128 --in_h 28 --in_w 28 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 1 --padding_w 1
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_weight -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_4.mlir
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=128 -in_h=28 -in_w=28 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 -t f16 --operation conv2d_bwd_weight
# File: e2e_for_pr/Resnet50_validation_nchw.mlir
#
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kcyx --in_layout nchw --out_layout nkhw --batchsize 64 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=128 -in_h=58 -in_w=58 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir
#
# Config: -fil_layout=kcyx -in_layout=nchw -out_layout=nkhw -batchsize=64 -in_channels=256 -out_channels=256 -in_h=56 -in_w=56 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --padding_h=0 --padding_w=0 --conv_stride_h=1 --conv_stride_w=1 --operation=conv2d_bwd_weight
# File: auto_e2e/conv2d_host_validation_f32_bwd.mlir
# Config: -batchsize=64 -groupsize=1 -in_channels=256 -in_h=56 -in_w=56 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkcyx -in_layout=ngchw -out_layout=ngkhw -t f32
# File: auto_e2e/Resnext101/F32_tests/Resnext101_f32_16.mlir
#
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 128 --in_h 58 --in_w 58 --out_channels 128 --fil_w 3 --fil_h 3 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=128 -in_h=58 -in_w=58 -out_channels=128 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_6.mlir
#
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 1024 --in_h 14 --in_w 14 --out_channels 256 --fil_w 1 --fil_h 1 --dilation_h 1 --dilation_w 1 --conv_stride_h 1 --conv_stride_w 1 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=256 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_2.mlir
#
# Config: --operation conv2d_bwd_weight -t f32 -fil_layout=kyxc -in_layout=nhwc -out_layout=nhwk -in_channels=256 -batchsize=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 -dilation_h=1 -dilation_w=1 -conv_stride_h=1 -conv_stride_w=1 -padding_h=1 -padding_w=1
# File: auto_e2e/conv2d_host_validation_f32_bwd.mlir
# Config: -batchsize=256 -in_channels=256 -in_h=14 -in_w=14 -out_channels=256 -fil_h=3 -fil_w=3 --dilation_h=1 --dilation_w=1 --conv_stride_h=1 --conv_stride_w=1 --padding_h=1 --padding_w=1 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f32
# File: auto_e2e/Resnet50/F32_tests/Resnet50_f32_9.mlir
#
# Config: --rand_type float --operation conv2d_bwd_weight -t f16 --fil_layout kyxc --in_layout nhwc --out_layout nhwk --batchsize 64 --in_channels 1024 --in_h 14 --in_w 14 --out_channels 2048 --fil_w 1 --fil_h 1 --dilation_h 1 --dilation_w 1 --conv_stride_h 2 --conv_stride_w 2 --padding_h 0 --padding_w 0
# File: auto_e2e/conv2d_host_validation_f16_bwd.mlir
# Config: -batchsize=64 -in_channels=1024 -in_h=14 -in_w=14 -out_channels=2048 -fil_h=1 -fil_w=1 --dilation_h=1 --dilation_w=1 --conv_stride_h=2 --conv_stride_w=2 --padding_h=0 --padding_w=0 --operation conv2d_bwd_weight -fil_layout=gkyxc -in_layout=nhwgc -out_layout=nhwgk -t f16
# File: auto_e2e/Resnet50/F16_tests/Resnet50_f16_1.mlir

# %%
## TODO: when rerunning this, account for rand-type differences
